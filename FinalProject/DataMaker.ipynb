# %%
#For reading and writing Twitter information:
import tweepy

#Importing the Data set
import sys, os
import pandas as pd

import numpy as np
import warnings

# %%
#Telling the code where to find our Twitter account:

#consumer_key = QrYHKUj5ULmFEeLHubKuJrKsx
#consumer_secret = ZtfvE5uIzUGCZEWa25jWmUpiRsKz7H5gpdOfDQRlH0LEEHVySj
#access_token = 1191741930847137792-IuJe34kSWdmaPqd19DB2V6RNWGMet4
#access_token_secret = yIuQm2ZLOCeEG61sAerzY2vKpuwFtVgqF2E2hyWymGN33

auth = tweepy.OAuthHandler("QrYHKUj5ULmFEeLHubKuJrKsx", "ZtfvE5uIzUGCZEWa25jWmUpiRsKz7H5gpdOfDQRlH0LEEHVySj")
auth.set_access_token("1191741930847137792-IuJe34kSWdmaPqd19DB2V6RNWGMet4", "yIuQm2ZLOCeEG61sAerzY2vKpuwFtVgqF2E2hyWymGN33")

api = tweepy.API(auth)

# %%
user = "GretaThunberg"

maxTweets = 10000
tweetsPerQry = 100
fName = "{0}_tweets.txt".format(user)

# Language code (follows ISO 639-1 standards)
language = "en"

# If results from a specific ID onwards are reqd, set since_id to that ID.
# else default to no lower limit, go as far back as API allows
sinceId = None

# If results only below a specific ID are, set max_id to that ID.
# else default to no upper limit, start from the most recent tweet matching the search query.
max_id = -1

tweetCount = 0
print("Downloading max {0} tweets".format(maxTweets))
with open(fName, 'w', encoding="utf-8") as f:
    while tweetCount < maxTweets:
        try:
            if (max_id <= 0):
                if (not sinceId):
                    new_tweets = api.user_timeline(id=user,tweet_mode = "extended", count=tweetsPerQry)
                else:
                    new_tweets = api.user_timeline(id=user,tweet_mode = "extended", count=tweetsPerQry,
                                            since_id=sinceId)
            else:
                if (not sinceId):
                    new_tweets = api.user_timeline(id=user,tweet_mode = "extended", count=tweetsPerQry,
                                            max_id=str(max_id - 1))
                else:
                    new_tweets = api.user_timeline(id=user,tweet_mode = "extended", count=tweetsPerQry,
                                            max_id=str(max_id - 1),
                                            since_id=sinceId)
            if not new_tweets:
                print("No more tweets found")
                break
            i = 0
            for tweet in new_tweets:
                try: text = tweet.retweeted_status.full_text
        
                except: text = tweet.full_text
        
                #print(i, text)
                i+=1
                f.write(text + '\n')
            tweetCount += len(new_tweets)
            print("Downloaded {0} tweets".format(tweetCount))
            max_id = new_tweets[-1].id
        except tweepy.TweepError as e:
            # Just exit if any error
            print("some error : " + str(e))
            break
# Out:
# Downloading max 10000 tweets
# Downloaded 100 tweets
# Downloaded 200 tweets
# Downloaded 299 tweets
# Downloaded 398 tweets
# Downloaded 498 tweets
# Downloaded 598 tweets
# Downloaded 697 tweets
# Downloaded 796 tweets
# Downloaded 896 tweets
# Downloaded 996 tweets
# Downloaded 1096 tweets
# Downloaded 1195 tweets
# Downloaded 1295 tweets
# Downloaded 1395 tweets
# Downloaded 1495 tweets
# Downloaded 1595 tweets
# Downloaded 1695 tweets
# Downloaded 1795 tweets
# Downloaded 1895 tweets
# Downloaded 1994 tweets
# Downloaded 2094 tweets
# Downloaded 2194 tweets
# Downloaded 2293 tweets
# Downloaded 2393 tweets
# Downloaded 2493 tweets
# Downloaded 2592 tweets
# Downloaded 2692 tweets
# Downloaded 2790 tweets
# Downloaded 2890 tweets
# Downloaded 2989 tweets
# Downloaded 3088 tweets
# Downloaded 3187 tweets
# Downloaded 3201 tweets
# No more tweets found
